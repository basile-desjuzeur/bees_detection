# %% [markdown]
# # <center> <u>**Pipeline détection de pollinisateurs** </u></center>

# %% [markdown]
# # 1. Importer un nouveau dossier (Justine)

# %% [markdown]
# 0.1. Dézipper les dossiers

# %%
! jar xvf "'/home/basile/Documents/projet_bees_detection_basile/justine_si_fuera_necesario/Nouvelles photos après 3mars-MAJ21avril.zip'" -C "/home/basile/Documents/projet_bees_detection_basile/data_bees_detection/justine_1_3"
# Out:
# /bin/bash: jar: command not found

# %% [markdown]
# 0.2 Réorganiser chacun des trois dossiers
#
# Pour l'instant, ils sont chacun organisés de la facon suivante :
#
# - base_path / dir / label / photograph / img_1.jpg
#
# On veut les réorganiser ainsi :
#
# - base_path / dir / label / photograph_img_1.jpg

# %%
# get paths
base_path = '/workspaces/projet_bees_detection_basile/data_bees_detection/'
directories = ['justine_1_3','justine_2_3','justine_3_3']

# %%
# function to reorganize data

def reorganize_data(path):

    directory = path.split('/')[-1]

    # loop over dir structure
    for root,dirs,files, in os.walk(path): 

        # loop over files
        for file in files : 

            old_path = os.path.join(root,file)


            # check if label/photo/img or label/im
            if len(old_path.split('/')) == 7 :

                continue

            photographer = root.split('/')[-1]
            label = root.split('/')[-2]
            new_name = photographer + '_' + file

            new_path = os.path.join(base_path,directory,label,new_name)

            # rename file
            os.rename(old_path,new_path)

    # delete empty directories
    for root,dirs,files, in os.walk(path):  

        # Loop over dirs
        for dir in dirs :

            dir_path = os.path.join(root,dir)

            if len(os.listdir(dir_path)) == 0 :

                os.rmdir(dir_path)

# %%
for directory in directories : 

    path = os.path.join(base_path,directory)
    reorganize_data(path)

# %% [markdown]
#                 genus_list.append(dir)
# .2. Tout ranger dans un seul dossier

# %%
new_path = os.path.join(base_path,'Justine')

# %%
def move_to_new_folder(path): 

    for root,dirs,files in os.walk(path): 

        # loop over files
        for file in files : 

            old_path = os.path.join(root,file)

            # get label
            label = old_path.split('/')[-2]

            #make dir if not exists
            if not os.path.exists(os.path.join(base_path,'Justine',label)):
                os.mkdir(os.path.join(base_path,'Justine',label))

            # new file name
            new_name = old_path.split('/')[-3] + file 

            # get new path
            new_path = os.path.join(base_path,'Justine',label,new_name)

            # move file
            os.rename(old_path,new_path)

# %%
for directory in directories : 

    path = os.path.join(base_path,directory)
    move_to_new_folder(path)

# %% [markdown]
# # 2. Nettoyer la structure des bases de données

# %% [markdown]
# 2.1 Anthophila

# %%
path = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/Anthophila"

# %%
# function to reorganize data

def reorganize_data_anthophila(path):

    directory = path.split('/')[-1]

    # loop over dir structure
    for root,dirs,files, in os.walk(path): 

        # loop over files
        for file in files : 

            old_path = os.path.join(root,file)


            # check if label/photo/img or label/im
            if len(old_path.split('/')) ==  len(path.split('/')) + 2 :

                continue

            photographer = root.split('/')[-1]
            label = root.split('/')[-2]
            new_name = photographer + '_' + file

            new_path = os.path.join(path,label,new_name)

            # rename file
            os.rename(old_path,new_path)

    # delete empty directories
    for root,dirs,files, in os.walk(path):  

        # Loop over dirs
        for dir in dirs :

            dir_path = os.path.join(root,dir)

            if len(os.listdir(dir_path)) == 0 :

                os.rmdir(dir_path)

# %%
reorganize_data_anthophila(path)

# %% [markdown]
# 2.2. DG

# %%
path = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/DG"
path_cleaned = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/DG_cleaned"

# %%
! mkdir "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/DG_cleaned"

# %%
def reorganize_data_dg(path): 


    for root,dirs,files in os.walk(path): 

        for file in files: 

            old_path = os.path.join(root,file)

            label = old_path.split('/')[-2]

            if not os.path.exists(os.path.join(path_cleaned,label)):
                os.mkdir(os.path.join(path_cleaned,label))

            # copy file
            new_path = os.path.join(path_cleaned,label,file)

            cmd = 'cp "' + old_path + '" "' + new_path + '"'
            os.system(cmd)

# %%
reorganize_data_dg(path)

# %% [markdown]
# Des dosssiers sont nommés avec le format suivant :
# Lasioglossum (Evylaeus) punctatissimum
#
# On enlève le sous genre entre parenthèses

# %%
import re 

def rename_folders(path): 

    for folder in os.listdir(path): 

        # look if parenthesis
        if '(' in folder :

            # get new name i.e without parenthesis and content
            new_name = re.sub(r'\([^)]*\)', '', folder)

            # remove if two consecutive spaces
            new_name = re.sub(' +', ' ', new_name)

            # get old path
            old_path = os.path.join(path,folder)

            # get new path
            new_path = os.path.join(path,new_name)

            # rename folder
            os.rename(old_path,new_path)

# %%
rename_folders(path_cleaned)

# %% [markdown]
# 2.3 Inat

# %%
path = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/inat_25_04"

# %%
def reorganize_data_inat(path): 

    for root,dirs,files in os.walk(path): 

        for file in files: 

            old_path = os.path.join(root,file)

            label = old_path.split('/')[-2]

            if not os.path.exists(os.path.join(path,label)):
                os.mkdir(os.path.join(path,label))

            # rename file
            new_path = os.path.join(path,label,file)

            os.rename(old_path,new_path)

    # delete empty directories
    for root,dirs,files, in os.walk(path):  

        # Loop over dirs
        for dir in dirs :

            dir_path = os.path.join(root,dir)

            if len(os.listdir(dir_path)) == 0 :

                os.rmdir(dir_path)

# %%
reorganize_data_inat(path)

# %% [markdown]
# 2.4 Inat  from axel

# %%
path = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/iNaturalist"
import re

# %%
def reorganize_data_inat_axel(path): 


    for root,dirs,files in os.walk(path): 

        for file in files: 

            old_path = os.path.join(root,file)

            # extract label from file name
            # file names are like Amegilla albigena2794.jpg 
            label = re.sub(r'\d+', '', file).split('.')[0]
        
            if not os.path.exists(os.path.join(path,label)):
                os.mkdir(os.path.join(path,label))

            # rename file
            new_path = os.path.join(path,label,file)
            os.rename(old_path,new_path)

    # delete empty directories
    for root,dirs,files, in os.walk(path):

        # Loop over dirs
        for dir in dirs :

            dir_path = os.path.join(root,dir)

            if len(os.listdir(dir_path)) == 0 :

                os.rmdir(dir_path)

# %%
reorganize_data_inat_axel(path)

# %% [markdown]
# 2.5 HS = OK

# %% [markdown]
# 2.6 LMDI

# %%
path = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/LMDI"

# %%
def reorganize_data_lmdi(path): 

    for root,dirs,files in os.walk(path): 

        for file in files: 

            old_path = os.path.join(root,file)

            label = old_path.split('/')[-2]

            if not os.path.exists(os.path.join(path,label)):
                os.mkdir(os.path.join(path,label))

            # rename file
            new_path = os.path.join(path,label,file)

            os.rename(old_path,new_path)

    # delete empty directories
    for root,dirs,files, in os.walk(path):

        # Loop over dirs
        for dir in dirs :

            dir_path = os.path.join(root,dir)

            if len(os.listdir(dir_path)) == 0 :

                os.rmdir(dir_path)

# %%
reorganize_data_lmdi(path)

# %% [markdown]
# 2.7 Spipoll

# %%
path = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/Spipoll"
import re

# %%
def reorganize_data_spipoll(path): 


    for root,dirs,files in os.walk(path): 

        for file in files: 

            old_path = os.path.join(root,file)

            # get label , which is t=stored in file name like Andrena fulva640.jpg
            label = re.sub(r'\d+', '', file).split('.')[0]

            if not os.path.exists(os.path.join(path,label)):
                os.mkdir(os.path.join(path,label))

            # rename file
            new_path = os.path.join(path,label,file)
            os.rename(old_path,new_path)


    # delete empty directories
    for root,dirs,files, in os.walk(path):  

        # Loop over dirs
        for dir in dirs :

            dir_path = os.path.join(root,dir)

            if len(os.listdir(dir_path)) == 0 :

                os.rmdir(dir_path)

# %%
reorganize_data_spipoll(path)

# %% [markdown]
# # 3. Création d'un seul dossier bien rangé

# %%
path_to_whole_dataset = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset"
path_to_whole_dataset_cleaned = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset_cleaned"

# %%
! mkdir "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset_cleaned"
# Out:
# 6132.00s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %%
def move_to_clean(path): 


    # loop over databases 

    for db in os.listdir(path): 

        db_path = os.path.join(path,db)

        # loop over labels
        for label in os.listdir(db_path):

            label_path = os.path.join(db_path,label)

            # create dir if not exists
            if not os.path.exists(os.path.join(path_to_whole_dataset_cleaned,label)):
                os.mkdir(os.path.join(path_to_whole_dataset_cleaned,label))

            # loop over files
            for file in os.listdir(label_path): 

                file_path = os.path.join(label_path,file)

                new_name = db + '_' + file

                # copy file
                new_path = os.path.join(path_to_whole_dataset_cleaned,label,new_name)

                cmd = 'cp "' + file_path + '" "' + new_path + '"'
                os.system(cmd)

# %%
move_to_clean(path_to_whole_dataset)
# Out:
# cp: -r not specified; omitting directory '/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/LMDI/Melittidae/Macropis'
# cp: -r not specified; omitting directory '/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/LMDI/Melittidae/Dasypoda'
# cp: -r not specified; omitting directory '/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/LMDI/Melittidae/Melitta'
# cp: -r not specified; omitting directory '/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset/inat_25_04/inat_4/Pictures'

# %%
# remove all empty directories in cleaned dataset
for root,dirs,files, in os.walk(path_to_whole_dataset_cleaned):

    for dir in dirs :

        dir_path = os.path.join(root,dir)

        if len(os.listdir(dir_path)) == 0 :

            os.rmdir(dir_path)

# %%
# remove all non wanted files extensions
import os

allow_list = ['jpg','JPG','jpeg','JPEG','png','PNG']

for root,dirs,files, in os.walk(path_to_whole_dataset_cleaned):

    for file in files : 

        file_path = os.path.join(root,file)

        if file.split('.')[-1] not in allow_list :

            os.remove(file_path)

# %% [markdown]
# # 4. Editions de csv_récapitulatifs

# %%
# edit csv file to sum up strucutre of dataset

import os 
import pandas as pd 

def edit_csv(path,output_path): 
    # csv must have columns : 
    # path,label

    # create dict
    dict = {}

    # loop over files
    for root,dirs,files in os.walk(path):

        for file in files: 

            # get label
            label = root.split('/')[-1]

            # get path
            file_path = os.path.join(root,file)

            # add to dict
            dict[file_path] = label

    # create df with path and label as columns
    df = pd.DataFrame.from_dict(dict,orient = 'index',columns = ['label'])

    # add path column
    df['path'] = df.index

    # drop index 
    df = df.reset_index(drop = True)

    # save to csv
    df.to_csv(output_path,errors = 'ignore')

# %%
path_whole_dataset = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset"
path_whole_dataset_cleaned = "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset_cleaned"


edit_csv(path_whole_dataset,"/workspaces/projet_bees_detection_basile/bees_detection/datafiles/classification/whole_dataset_230628.csv")
edit_csv(path_whole_dataset_cleaned,"/workspaces/projet_bees_detection_basile/bees_detection/datafiles/classification/whole_dataset_cleaned_230628.csv")

# %% [markdown]
# # 5. Filtrer le dataset
#
# Avec les contraintes suivantes :
#
# - Uniquement des images labelisées au niveau de l'espèce
# - Nombre d'images par espèces compris entre 50 et 10000
#
# (NB : cette dernière étape aurait pu se faire différement :
# pour les espèces avec plus de 1000 img; faire tourner yolo sur
# toutes les images et prendre les 1000 avec le plus gros score
# de confiance )

# %%
import pandas as pd 
import os

# %%
df_whole_dataset_cleaned = pd.read_csv("/workspaces/projet_bees_detection_basile/bees_detection/datafiles/classification/datasets/whole_dataset_cleaned_230628.csv")

df_whole_dataset_cleaned.head()
# Out:
#    Unnamed: 0               label  \
# 0           0  Hylaeus hyalinatus
# 1           1  Hylaeus hyalinatus
# 2           2  Hylaeus hyalinatus
# 3           3  Hylaeus hyalinatus
# 4           4  Hylaeus hyalinatus
#
#                                                 path
# 0  /workspaces/projet_bees_detection_basile/data_...
# 1  /workspaces/projet_bees_detection_basile/data_...
# 2  /workspaces/projet_bees_detection_basile/data_...
# 3  /workspaces/projet_bees_detection_basile/data_...
# 4  /workspaces/projet_bees_detection_basile/data_...

# %%
def accept_label(label): 

    # 1. are species

    # in one word
    if len(label.split(' ')) == 1 :
            
        return False

    # contains ' sp'
    elif ' sp' in label : 

        return False
    
    else : 

        return True
    
# remove labels that are not species
df_whole_dataset_cleaned['species'] = df_whole_dataset_cleaned['label'].apply(accept_label)

# remove labels that are not species
df_whole_dataset_cleaned = df_whole_dataset_cleaned[df_whole_dataset_cleaned['species'] == True]



# more than 50 images per label
df_whole_dataset_cleaned = df_whole_dataset_cleaned[df_whole_dataset_cleaned.groupby('label').label.transform('count') > 50]

# %%
accept_label('Coelioxys')
# Out:
# False

# %%
df_whole_dataset_cleaned['label'].value_counts().describe()
# Out:
# count      258.000000
# mean      1192.507752
# std       4027.105664
# min         51.000000
# 25%         86.000000
# 50%        190.500000
# 75%        529.750000
# max      49611.000000
# Name: count, dtype: float64

# %%
labels = df_whole_dataset_cleaned['label'].unique()

# create dict
dict = {}

# loop over labels
for label in labels :

    # get label count
    label_count = df_whole_dataset_cleaned[df_whole_dataset_cleaned['label'] == label]['label'].count()

    # add to dict
    dict[label] = label_count

# create df
df = pd.DataFrame.from_dict(dict,orient = 'index',columns = ['label_count'])

# sort df
df = df.sort_values(by = 'label_count',ascending = False)

df.to_csv("/workspaces/projet_bees_detection_basile/bees_detection/datafiles/classification/whole_dataset_cleaned_nb_img_per_labels_230628.csv")

# %%
# cap number of pictures per label to 1000

df = df_whole_dataset_cleaned.copy()

# Group the dataframe by the '#label' column
grouped = df.groupby('label')

# Create an empty list to store the filtered data
filtered_data = []

# Iterate over each group
for label, group in grouped:
    if len(group) >= 1000:
        # If the group has 1000 or more paths, add only 1000 paths
        filtered_data.append(group.sample(1000))
        
    else:
        # If the group has fewer than 1000 paths, add all of them
        filtered_data.append(group)

# Concatenate the filtered data into a new dataframe
df_filtered = pd.concat(filtered_data)

# Reset the index of the filtered dataframe
df_filtered = df_filtered.reset_index(drop=True)

# %%
df['label'].value_counts().describe()
# Out:
# count      258.000000
# mean      1192.507752
# std       4027.105664
# min         51.000000
# 25%         86.000000
# 50%        190.500000
# 75%        529.750000
# max      49611.000000
# Name: count, dtype: float64

# %%
df_filtered['label'].value_counts().describe()
# Out:
# count     258.000000
# mean      356.635659
# std       343.630478
# min        51.000000
# 25%        86.000000
# 50%       190.500000
# 75%       529.750000
# max      1000.000000
# Name: count, dtype: float64

# %%
df_filtered.head()
# Out:
#    Unnamed: 0              label  \
# 0      212667  Amegilla albigena
# 1      212668  Amegilla albigena
# 2      212669  Amegilla albigena
# 3      212670  Amegilla albigena
# 4      212671  Amegilla albigena
#
#                                                 path  species
# 0  /workspaces/projet_bees_detection_basile/data_...     True
# 1  /workspaces/projet_bees_detection_basile/data_...     True
# 2  /workspaces/projet_bees_detection_basile/data_...     True
# 3  /workspaces/projet_bees_detection_basile/data_...     True
# 4  /workspaces/projet_bees_detection_basile/data_...     True

# %%
# drop column species, Unnamed: 0
df_filtered = df_filtered.drop(columns = ['species','Unnamed: 0'])

# save to csv
df_filtered.to_csv("/workspaces/projet_bees_detection_basile/bees_detection/datafiles/classification/datasets/whole_dataset_cleaned_only_species_50_1000_230628.csv")

# %% [markdown]
# 5.1 Create new folder for classication

# %%
! mkdir "/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset_cleaned_only_species_cap_50_1000_230628"

# %%
# clean dataset

files = os.listdir("/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset_cleaned")

files = [file for file in files if not os.path.isdir(os.path.join("/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset_cleaned",file))]

for file in files :
    os.remove(file)

# %%
import os

def new_path(path, output_path="/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset_cleaned_only_species_cap_1000"):
    
    # Get label
    label = path.split('/')[-2]

    new_path = os.path.join(output_path, label)
    
    return new_path



def move_to_folder(df, output_path, new_path_func):



    # Change path column
    df['new_path_desti'] = df['path'].apply(lambda x: new_path_func(x, output_path))

    # Loop over labels
    for label in df['label'].unique():

        print('Moving label: ', label)

        # Create directory if it does not exist
        if not os.path.exists(os.path.join(output_path, label)):
            os.mkdir(os.path.join(output_path, label))

        # Loop over files
        for i, file in enumerate(df[df['label'] == label]['path']):
            
            # Get new path
            new_path = df[df['label'] == label]['new_path_desti'].iloc[i]

            file_name = file.split('/')[-1]

            new_path = os.path.join(new_path, file_name)


            # Copy file
            cmd = 'cp "' + file + '" "' + new_path + '"'

            os.system(cmd)

# %%
move_to_folder(df_filtered,"/workspaces/projet_bees_detection_basile/data_bees_detection/whole_dataset_cleaned_only_species_cap_1000",new_path)
# Out:
# Moving label:  Aglaoapis tridentata
# Moving label:  Amegilla albigena
# Moving label:  Amegilla garrula
# Moving label:  Amegilla magnilabris
# Moving label:  Amegilla quadrifasciata
# Moving label:  Ammobates punctatus
# Moving label:  Ammobatoides scriptus
# Moving label:  Andrena aeneiventris
# Moving label:  Andrena afrensis
# Moving label:  Andrena agilissima
# Moving label:  Andrena albopunctata
# Moving label:  Andrena allosa
# Moving label:  Andrena ampla
# Moving label:  Andrena angustior
# Moving label:  Andrena apicata
# Moving label:  Andrena argentata
# Moving label:  Andrena asperrima
# Moving label:  Andrena assimilis
# Moving label:  Andrena barbarea
# Moving label:  Andrena barbareae
# Moving label:  Andrena barbilabris
# Moving label:  Andrena batava
# Moving label:  Andrena bicolor
# Moving label:  Andrena bicolorata
# Moving label:  Andrena bimaculata
# Moving label:  Andrena binominata
# Moving label:  Andrena bucephala
# Moving label:  Andrena carantonica
# ...

# %% [markdown]
# # 6. Prédictions sur le dataset filtré

# %% [markdown]
# 6.1 Prédictions sur tout le dataset

# %% [markdown]
# 6.1.1 Division du dataset pour pouvoir alléger la mémoire

# %%
import pandas as pd
import os

# read_csv and 
df = pd.read_csv("/workspaces/projet_bees_detection_basile/bees_detection/datafiles/classification/datasets/whole_dataset_cleaned_only_species_50_1000_230628.csv")

# create folder to store mulitple csv outputs 
folder_path = "/workspaces/projet_bees_detection_basile/bees_detection/datafiles/classification/datasets/whole_dataset_cleaned_only_species_50_1000_230628"

if not os.path.exists(folder_path):
    os.mkdir(folder_path)

df.describe()
# Out:
#          Unnamed: 0
# count  92012.000000
# mean   46005.500000
# std    26561.720822
# min        0.000000
# 25%    23002.750000
# 50%    46005.500000
# 75%    69008.250000
# max    92011.000000

# %%
# get number of rows
n_rows = df.shape[0]

# get number of rows per csv
n_rows_per_csv = n_rows // 100

# loop over csv
for i in range(100):

    # if i is not the last csv
    if i != 99:
            
            # get df
            df_csv = df.iloc[i*n_rows_per_csv:(i+1)*n_rows_per_csv,:]

            # save to csv
            df_csv.to_csv(os.path.join(folder_path,'whole_dataset_cleaned__only_species_cap_1000_230628_' + str(i) + '.csv'))

    # if i is the last csv
    else :
          
            # get df
            df_csv = df.iloc[i*n_rows_per_csv:,:]

            # save to csv
            df_csv.to_csv(os.path.join(folder_path,'whole_dataset_cleaned__only_species_cap_1000_230628_' + str(i) + '.csv'))

# %% [markdown]
# 6.1.2 Prédictions sur chaque csv

# %%
import os 


folder_path = "/workspaces/projet_bees_detection_basile/bees_detection/datafiles/classification/datasets/whole_dataset_cleaned_only_species_50_1000_230628"

list_csv = os.listdir(folder_path)
list_csv_path = [os.path.join(folder_path,file) for file in list_csv]

for csv_path in list_csv_path : 

    cmd = "python3 /workspaces/projet_bees_detection_basile/bees_detection/src/yolo/predict.py -i '"+csv_path+"'"
    os.system(cmd)
# Out:
# 2023-06-29 14:32:29.587546: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-29 14:32:29.615012: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 14:32:31.775728: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %% [markdown]
# 6.3 Un seul csv de toutes les prédictions
